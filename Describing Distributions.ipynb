# %% [markdown]
# # Describing Distributions
# Nokuthula Mchunu

# %% [markdown]
# The features to analyze:
#
#  1. VitD_levels
#  2. Doc_visits
#  3. TotalCharge

# %% [markdown]
# For each feature listed:
#
# 1. Plot a histogram with a kde (kernel density estimate)
# 2. Add a line for the mean (red)
# 3. Add a line for the median (green)
# 4. Add a line for for +1 std from the mean (black)
# 5. Add a line for the - 1 std from the mean (black)
# 6. Highlight the range between +1 and =1 std (yellow)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = '/Users/noksmchunu/Downloads/data-5.csv'
df = pd.read_csv(url, index_col = 0)
df.head()
# Out:
#             Lat       Lng      Area  Children  Age    Income   Marital  \
# State
# AL     34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# FL     30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# SD     43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# MN     43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# VA     37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#        Gender  ReAdmis  VitD_levels  ...  Hyperlipidemia  BackPain  Anxiety  \
# State                                ...
# AL       Male        0    19.141466  ...             0.0       1.0      1.0
# FL     Female        0    18.940352  ...             0.0       0.0      0.0
# SD     Female        0    18.057507  ...             0.0       0.0      0.0
# MN       Male        0    16.576858  ...             0.0       0.0      0.0
# VA     Female        0    17.439069  ...             1.0       0.0      0.0
#
# ...

# %% [markdown]
# For VitD_levels

# %%
# Ploting VitD_levels

col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability', discrete=True, kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# Answer the following questions: for VitD_Level
# 1. Is it Discrete or Continuous?
#     a. Continuous
# 3. Does it have a skew? If so, which direction (+/-)
#     a. Normal
# 5. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#    a. Leptokurtic

# %% [markdown]
# Doc_visits

# %%
# Ploting VitD_levels

col1 = 'Doc_visits'
feature = df[col1]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability', discrete=True, kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col1}')
ax.legend();

# %% [markdown]
# Answer the following questions: for Doc_visits
# 1. Is it Discrete or Continuous?
#     a. Continuous
# 3. Does it have a skew? If so, which direction (+/-)
#     a. Normal
# 5. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#    a. Mesokurtic

# %%
# Ploting VitD_levels

col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability', discrete=True, kde = True)
ax.axvline(mean,color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
Answer the following questions: for TotalCharge
1. Is it Discrete or Continuous?
    a. Discrete
3. Does it have a skew? If so, which direction (+/-)
    a. Positively skewed
5. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
   a. Platykurtic
